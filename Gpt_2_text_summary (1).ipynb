# %%
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.2 MB 4.3 MB/s
# ...

# %%
# !pip install sacremoses
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 880 kB 4.2 MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=c4401c10572e1ac20cb54667d0e894b0e9a9182d593e7fbeaa7adc925d3cd37a
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# ...

# %%
# !pip install transformers
# !pip install bert-extractive-summarizer
# !pip install spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.4 MB 4.1 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 33.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 55.1 MB/s
# ...
#      |████████████████████████████████| 101 kB 11.7 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from summarizer import Summarizer,TransformerSummarizer

# %%
body = '''Thank you. There you go. This is it, this is official, this is recorded okay. Yeah I can also I can also share the recordings once we finish the call. Okay? Of course please go ahead. Sure. So basically uh I am working on the project I'm working on um with the platform where users can can engage with brands, retail brands and uh via tokens. Um So this platform will be based on partnerships with wit and brand. So this platform will be all in one platform where retail brand can offer utility token uh and basically collectible N. F. C. S. For the utility token part. So it will hello users to engage his brands. So they can be they can earn those you can buy instead uh those for earning those utility token for the brands. Uh That you would be too to have some kind of games like quiz where user can engage on games and the ability to learn those they could earn also those utility to come through the future of sharing the online shopping experience with those brands to the network on this platform. Um The idea behind that is um there will be a plug in set up on the website, The online stores of those partner retail brands. Where each time a user make a transaction, the transaction that I would be called on to our platform and the users would have the option to share those transaction details. Uh So basically the item they bought at which price and let's say with a picture you could share those details with their network and if they do so they would have basically the possibility to earn a utility token. So there would be a few ways for users to use two of those brands. Um And thanks to those new T. T. Token once the oldest utility token depending on the amount of futility taken the old into the digital wallets. Uh that would be integrating to the price of all. That will be part of the platform. They could access um exclusive offers. So that would be exclusive exclusive products or exclusive events. So that's the I. T. Behind the U. T. T. To kind of the brands the partner brands on this platform. So that will be one aspect of the platform. Also on the we imagine that this platform would be built around like three basically three tabs. So one time will be the user profile. Once the user log into the platform could access is um digital rate and check the different token that has either utility token, NFK collectible and FTS. And also a form of of token related to the brands that will come to this little option later for the last part of the kind of talking that way we can talk about on this profile to check to the different online transaction he made with the met with the retail partners. And last you will set your son is user profile the status that he that he asked that he would have earned with those uh little brands through the the level of utility in his portfolio. So if he owned a certain amounts of city could reach a certain level of let's say membership. Uh that will give him access to even more exclusive offers. So the idea first that user gets onto the platform, they will be like first you could check it should light emits from talking about as well as they could shake the different online transactions that he made with the retail partners. And also you could check his statues that he would have burned with the brands and that will give him access to different kinds of offers also. And one main aspect of this um This platform is another tab will be the brand page. So once use your access to this part of the app as well. Uh you could check the different brand page of the retail partners and each brand page will be divided in few parts. The first part basically will be the different games that the brain has to have found the platform I think as an M. V. P. To be mostly quizzes. 2nd part will be um polls that the brands will offer to the users to take part too. So it's basically like questions about, let's say it could be like a decision making about designs about Uh kind of partnership he wants the the users wants to see the brands to have with. Um and so so basically it's polls that the user could take part two and help influence decision making of the brands. We can imagine that to participate to just pulls the user would have to hold a certain amount of token portfolio. So we make even more sense for the brands to have users who are utility token to vote on those poles and to have more like weight into the decision making. So the second part will be pulls their games, pulls will be the exclusive offer that the brands will currently offer to the users. So depending on the and each offer will specify the amount of fut two taken that uh the users need to hold in the digital world to access to those offers. So we could imagine again that would be offers related to special limited edition of products or products offer in exclusivity like before launch or it could be as well access to special events. So that would be the self that all the offers currently offered to the the users on the platform. The 4th part will be uh different collectible N. F. T. S. That the brand would be selling. Um So basically it would be like kind of about where the brand could just expose and sell the collectible N. F. T. S. Um So basically in the M. V. P. Of the platform I mentioned those focus um for this brand page. So mentioned again, polls exclusive offer And 4th part will be the collectible entities. I imagine other parts of the brand page but it would be for further vegetables I can mention, we'll discuss, we could discuss later stage we we go there. Um and so you have on this platform your early mentions three parts. So you have the user profile, you have the brand page and you love like what I call the community as community aspect community where the users can check what the users uh the the interaction with the brands are. So this will be like in a social network dedicated to shopping experiences and interaction with brands of the different users. So users could share the shopping experience with the network. Um and basically through that sharing they will they will Egyptian to eternity token. But basically it would be a social network where you could check what he poses by or also ways of interaction with the brands. For example the polls that the answer to the quiz or but mostly imagine it like as a basically where you could check what your friends or what the users like publicly of the public basically buying with the brand. For me it's interesting to know what my friends by, what kind of pictures they make. Give me the option to have an idea of what my friends own. And as well I decided to buy. And so it's pretty much like really a social network dedicated to buying experience. Um so yeah that will be it basically in the MPP three parts user profile, brand page and the community part. So in terms of technical requirements obviously, uh, and that was my question. It will be the integration of digital wallet as well. Elections where you can exchange your token, there will be as well kind of plug in that you could uh put on the partner online stores where users can call data, transaction data as um, and this is the third aspect would be so the social network. So you have a digital right slash exchange your plugging and you have this aspect of community where users can share experiences and basically the option to kind of comment slash communicates on those experiences. So that's about the specimen it for the peach. The requirements after the project is still intact. Yeah, so hated also have a couple of questions here. Right? So how are these brands on board onto the platform? So this will a partnership. And the idea is that the brands would have and access through like straight into the brain access to the platform. It's like an enemy access where they can basically themselves um seeded into the different parts of the brand page and decide themselves about what quiz, what polls what offers uh, they will put on the front page. So it's really like a collaboration where the platform, the brands will have access uh, to interface if you want interface. This Yeah, so brands will have access to all had been um, as a bad man module where they would have the provisions to say one? They would have the provision to list their tokens. Second would be they would have the provision to say add the promotions that are currently available, maybe display the set of coupon codes or something like that. Any promotions that they have, they will be able to list it there. They will also have a provision to list some of the products that they're selling, which when the user clicks should take it to their site, right? For example, if it's on amazon and take them to amazon Yes, exactly, like it would be like where you see what the product will be like and they will link it to the page understood. Okay, so, uh, one question here, like the token aspect of things. Right? So, uh, that kind of introduces one challenge because which are block chains, are we looking to launch this on? So that's the question that the token, the way I said you will be uh, under standard of Yossi, 20. the way I see it. So, uh, and The idea would be obviously to be like a layer two solution, so gas fees will be lower. Um, it could be Arbitron, uh, polygon, I would imagine, but yes, the way I see it is, there would be like conduct I understand, so paul Egan is something that we support as well and I think it would be a good choice. But one thing I need to understand further is when the brands come onto a platform and list their tokens, right, Have they already have the brands already deployed the tokens or are we deploying the tokens on behalf of the brand? Yes, will be deployed. The judge will be, we will deploy the token on girl from the brand. So there will be like
 yes, that's the idea is to it's uh only one platform where we take care of the issues of the tokens. But then once it's issued we offer the service of the exchange as I mentioned. But most of the thing is as of now, uh, it's brands, they don't have your token basically most of the brands don't have youtube. And so the, the idea would be that we issue for them on this platform or well for the service of issues or statistical for them. So they would be like a kind of token of frame jewish um, like part so that's part of my questions for you guys. That's something you can offer also like where there's a, at first production for this uh, brand new tt token Yeah, definitely. That can be set up. So the only prerequisite would be that we would receive say a token and the token metadata like say what do you want the tokens name to be the the auction prices, supply and that's the three part of the discussion. Yeah, so in the, in the brand's admin portal, suburban portal they would need to specify this information and we can launch the tokens accordingly. So one the next next next question that I have is if then the user comes into the platform um are they going through any K Y C. Process? I don't think so. No there will be um you will be there looking with your emails. Um The other questions would be like uh the option either to connect the digital right of them to have like a specific word for the platform. I know some competitors that have some of them they have the bullets like a specific date for the platform or some of them have just the option to connect like specific. Yes exactly. Meet the Moscow front um also I mean but yeah, so that's a discussion to have what makes more sense to have the option to have. Um So so the thing is we can either we can do both ways actually. So once the user logs in they can connect their wallet. So when they connect their wallet, if they don't have a wallet we can create a wallet on behalf of them on the platform itself, yep. So that can be associated with the login. So when they login they would have the platform basically a custodial platform on wallet where they will be able to make the purchases of tokens. So another question are we are we launching a platform token as such? The platform took, you mean like connections our own native token. Say what? Yeah. Yeah. Yeah well that's the discussion um I mean there are two equities is like one of them is we don't know that we do um and still pondering this feature, I know some Cupids just do some of them don't ask them to but at a later stage um I think that if you want to have a launch like a bit like a faster launch, I would say a bit leaner lunch maybe it would be better without. But then again I'm open to open to a discussion on this part. That's why I need a partner to give me insight and like according to the like police experience, what do they think about that aspect? Okay I asked that because I wanted to understand when I say amazon is also on a platform and I wanted to purchase some amazon tokens, would I be making that purchase by slapping our platform? I think at first you will be without like they could buy straight away with a serum or even the U. S. B. C. Or whatever. Yeah it makes it makes it makes the process easier but that okay so once the user has the the native amazon token, what can they do with it basically just reading them on the partner side. Right. So first of all um yeah there are two things um First depending on the number of tokens having uh digital read, they could access if they have enough token specific kind of offers. Well, events, let's say. Uh I mean I don't like the term of amazon, but let's, if night has organized like a private event, a private cell, If you're like 190 tokens in your portfolio, you could access to the students. So it's like kind of a pre condition uh to have enough token to access this and once you access this and you actually disabled and you don't have any deduction of tokens, therefore Right, it's just like a condition to access once you access this event you should have enough tokens, then let's we can imagine that you could buy some products of some other services, You could read him those tokens. So there are two aspects um once is like a clinician to anim portfolio to access this like offers and second you can read him yes, uh to to buy services or products that our offers limited, I don't know if I'm being clear there, but yeah, that's that's so that is fine. So um I think the housing clarity on the the vendor coming in and launching their stuff and users purchasing. So what all were the next stages. I remember you mentioning something about a wallet and plug into an extension. Right? So can you repeat that again? Yeah, about the plugging. So for me it's important. Part islam and actually a decision, We mentioned two for me competitors slash inspirations that I'm just kind of or like aspects on the labs. one of them is called Storm and Go Well, but then and the storm x as basically is based on the plug in there with the partners and the retail partner brands where basically if your user of soul mix And you, let's say you buy your products with one of the retail partners, let's in 19 You buy with from the website of 90 some products through the plug in and the transaction that would be cruel to stomachs application and actually depending on the amount you both on the Nike portal website, you will get a specific amount of, let's say Bitcoin as a cash back in general. Like like honey. Right. Exactly. It's like a chrome extension. So the idea would be like to crawl the transaction data and instead of actually at an early stage for the NdP stage instead of having cash back, it will be just like the ability to actually see the transaction meters only a portal user profile and then to be able to share it with your network and the fact that you share it with your network, it will give you some muted the ratio will depend what the brand decides. Um, but yeah, I need to have like kind of prom extension of plugging that will crawl transaction retail and feed into your user profile. Okay, understood understood. So um, thought so again here also there will be and I've been paneled for there will be an option within the I've been banging for the brands to decide how much the payout is going to be right or is that something that we decide? No no no that's that's what you have to learn up to the brand. Okay. So stay for example, Nike is our partner, they're they're already on our platform. So I have I bought a couple of Nike tokens with the U. S. D. C. And I have 100 Nike tokens and I go to Nike and I purchase. Okay cool. There is a private Nike shoe sale and I make a purchase i by using the Nike tokens. So at this particular moment that transaction has now made that Okay I have a wallet address basically I was linked to are used basically it out. Nike tokens was used to send as a payment to Nike so that people record on to that particular wallet or to that particular chrome extension we would be in the chrome extension we would say okay you have one x amount of tokens or is that is that is that again, tokens or is that just points in the general? No I mean for the extension for me it's just too at this stage would be just to basically to crawl transaction information. Um but we can imagine also that so any kind of transaction you make on the website. So if it's at first he has nothing to do with the private cell. You just crawl the transaction data until your user profile and all news the approval you have. The aggregate of the transaction that you have with this brand and then you can decide to share with your with your community. Right? That's one aspect. The other aspect that was much regarding the is that you can imagine that you will have private let's say private events organized like just for the users of the platform basically. So the user they could access it that enough detail in just roll it and then uh you don't want to access it. We can imagine so that they will be redirected to a part of the retail brand website that will be accessible only through the platform. Right. And then they could yeah they could basically uh let's purchase those uh those those products or items with with us D. C. Of with beauty taken if the brand allows them to do so. Right. Um So yes that's about it understood. So um next stage is basically I keep wearing the transactions and when it gets a hit we will just send some tokens to the particular wallet. Others okay. Okay that is fine. Um There was another aspect of where you mentioned wallet use case. Right. Yes. So can you elaborate the wallet use case a bit more? The wallet use case. Um Yes sure. I mean, uh, so as of now we, we did discuss one wallet, this is going to be a custodial wallet within the platform. I just wanted to understand if they're building also building something like meta mask where there is a chrome extension wallet also. No, that's, that's that, there was no question I was asking at first he's um, is it worth having the own wallet integral like for the platform or just like a connection with a mask? Connection with the mask is the easiest way to do and because otherwise I would feel like we would be reinventing the wheel a lot. It's already out there. You just have to, we can, yeah, we can like this. I know some, I know some competitors that their own wallet at first, but I believe it's also easier to just connect to uh, what its existing units such as meta my skin, yep. Uh okay, so I guess that is it from me in terms of questions. So team Sabah and sorry, uh, do you have any questions I wanted to ask if if you already have any competitors or you have, you already have any platform similar to the one we are breathing. So um, The one I will um, we quote will be social dot com. That does that for sports clubs. Social social social,
 S O C I O. S. Okay, so she was dark. Got it. Yeah, they do basically took us for all the clubs like PSG juventus Estonia so and they don't have the social feature, the community features but what do they well they don't have I mean there are actually some but what the strength is to strike partnership with clubs and offer them to issue for them the U. T. Taken. And pretty much like what I said about the offers like pools and exclusive offer the yeah there's this part in the apps. So that's one of the inspirations social dot com and they also will be a storm that I mentioned that leverage let's say like cryptocurrencies with e commerce. So they have like plugging onto partner retail brands and they offer cash backs to the users purchasing on the website of the retail brands. So to inspiration switches dot com in the storm. Okay so I have one more question. You mentioned the our N. F. D. U. S. Case. Right. The social aspect of things. So why are we using N. F. T. S. Can you just explain that again? Yeah I mean N. F. T. Would be too to add another aspect of Blockchain based tokens for brands. So brands could offer the I mean yeah offer the ut it is going to sort of the users slash consumer can engage more with them but also under brand. They just sell uh we can imagine they could just sell them so one school they could sell the collectible. I mean right now um it's more like luxury brand that also already some N. F. T. S. But we can imagine that more and more retails. I mean we can see it already with Advisor with Mcdonald's burger king. They already offer some as our own collectible energies. Uh Yeah. Would these NFS say for example Nike is is a Nike has listed a couple of the N. F. T. S on our platform. Okay. So would can I as a user purchase these N. F. T. S using just magical ethereum tokens or do I need to purchase Nike tokens first? You mean you know, you could you could buy the amenities with with us this year term. You wouldn't need to buy with you could, I mean if you agree on the value that there is but you don't need to does the point legal point on the street. Yeah that's that's clear. So so I don't know. I don't know. Is there any question? Actually nothing from nothing from nothing further from me. Okay. It's a perfect. So Theobald, I think the me and our team got a high level idea on preparing the constant data protection document. Uh basically how one of the process we follow is we'll be preparing a concept current vision document uh and that will be shared with you and once you give every green signal that we are on the same page. What whether we have captured all the features that we have mentioned over the call then they will be moving on to the proposal states this is the process where we follow. Yeah. Yeah. So I mean like to add on any points or something. Uh no nothing more. I think we have covered the entire thing. The technical team has understood the requirement and B. S captured everything. So let us wait for the C. I. D. Document and then we could have a walk through and understand if we are on the same page. Okay, understood. So also you also mentioned that there is a design discussion that you will be providing the designs with us or we need to build it from scratch with our team. Well, I've got basically there will be a scope of work already with an idea of the users, the work goes, but the design itself now is not done yet, that's that's your question. Workflows would be kind of detail with with the scope of work but there would be proper design of the platform itself, so we have to start from scratch. Okay then I think I think we have a session with their design team as well regarding the same. Okay, but more importantly was more economy, was this discussion we just had for the technical aspect and the structure slash architecture of this platform. So I guess that's the most important part. Um so once we get the document and we see well on the same page then we can move to the design terribly. So cool. I think that is it. Uh Well thank you so much for joining the session. And uh we'll be preparing the document. So we will be we'll be taking around 2.5 day, a maximum of three days to prepare the document. If it is done early, I can share that over. So I'll be in touch, I'll be in touch. Thank you so much. Thank you very much. Thank you again. Thank you so much. Have a good day. You two guys have a good day. Bye. Thanks everyone. Bye bye mm. Either.'''

# %%
bert_model = Summarizer()
bert_summary = ''.join(bert_model(body, min_length=60))
print(bert_summary)
# Out:
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.25G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
GPT2_model = TransformerSummarizer(transformer_type="GPT2",transformer_model_key="gpt2-medium")
full = ''.join(GPT2_model(body, min_length=60))
print(full)
# Out:
# Downloading:   0%|          | 0.00/718 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# ...

# %%
model = TransformerSummarizer(transformer_type="XLNet",transformer_model_key="xlnet-base-cased")
full = ''.join(model(body, min_length=60))
print(full)
# Out:
# Some weights of the model checkpoint at xlnet-base-cased were not used when initializing XLNetModel: ['lm_loss.bias', 'lm_loss.weight']
# - This IS expected if you are initializing XLNetModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLNetModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...
